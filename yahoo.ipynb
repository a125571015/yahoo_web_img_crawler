# %%
import requests
from bs4 import BeautifulSoup
import os
import json
import random,time
from random import randint
import re
import urllib
import sys
from urllib import request
from datetime import datetime
import pandas as pd
from pandas.core.frame import DataFrame
from datetime import datetime


####建立資料夾
def create_mkdir():
    #高麗菜，小黃瓜，紅蘿蔔，馬鈴薯，蘋果，雞腿肉，杏鮑菇，白蘿蔔，雞蛋
    #cabbage Gherkins, carrots, potatoes, apples, chicken legs, pleurotus eryngii, white radishes
    create_save_img_dir_list=["egg","tomoto","高麗菜","小黃瓜","紅蘿蔔","馬鈴薯","雞腿肉","蘋果","杏鮑菇","白蘿蔔"]
    mydir_img="save_img"
  
    if os.path.exists(mydir_img):
        print('mkdir name save_img has been create')
    else:
        os.mkdir(mydir_img)
    for i in create_save_img_dir_list:
        if os.path.exists("./save_img/{}".format(i)):
            print("dir name {} has been create".format(i))
        else:
            os.mkdir("./save_img/{}".format(i))
#寫檔相關 
def save_img(img_count,img_class,img_url):
    
    time.sleep(3)
    #print("進入寫入圖片前")
    request.urlretrieve(img_url, './save_img/{}/{}.jpg'.format(img_class,img_count))#寫入圖片
    #print("圖片下載完成")
    
    #print("image not found")
def save_img_url_log(img_count,):
    with open('./save_img_log/'+str(img_count)+'_log'+'.txt','w',encoding="utf-8") as es2:
        es2.write()
#網路控制相關
def random_headers():
    headers_list = [{'User-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0'},{'User-agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}]
    headers=random.choice(headers_list)
    print(headers)
    return headers
        

def get_next_main(url,headers):
    ss=requests.session()
    res=ss.get(url,headers=headers)

    json_string=res.text
    inside_article= json.loads(json_string)
 
    test=inside_article['html']
    total=inside_article['meta']['total']
    soup=BeautifulSoup(test,'html.parser')
    return soup
    
def get_main_body(url,headers):
   
    ss=requests.session()
    res=ss.get(url,headers=headers)
   
    res_status_code=res.status_code
    print(res_status_code)
    
    if res_status_code!=200:
        proxy_list=[{'https':'59.124.224.180:3128','http':'59.124.224.180:3128'},{'https':'113.196.140.162:8888','http':'113.196.140.162:8888'}]
        #proxy_list2={'http':'http://220.135.165.38:8080','https':'220.135.168.38:8080'}
        proxy=random.choice(proxy_list)
        
        print("進入proxy狀態,ip已經被鎖定")       
        cookies=ss.cookies.get_dict()
        time.sleep(2)
        
        res=ss.get(url,headers=headers,proxies=proxy ,cookies=cookies)
        soup=BeautifulSoup(res.text,'html.parser')
        return soup
            
            #print(res.json())    
    else:
        cookies=ss.cookies.get_dict()
        #print(ss.cookies.get_dict())
        time.sleep(2)
        res=ss.get(url,headers=headers,cookies=cookies)
        soup=BeautifulSoup(res.text,'html.parser')
        return soup
#初始化變數
create_mkdir()
img_class="白蘿蔔"#要爬甚麼資料
url="https://tw.images.search.yahoo.com/search/images;_ylt=AwrtSSggIghfEN4AAkZt1gt.;_ylu=X3oDMTBsZ29xY3ZzBHNlYwNzZWFyY2gEc2xrA2J1dHRvbg--;_ylc=?p={}&fr=yfp-search-sb&fr2=sb-top-tw.images.search&ei=UTF-8&n=60&x=wrt".format(img_class)
headers={'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0'}
img_count=1#圖片數量


headers=random_headers()
soup=get_main_body(url,headers)

main=soup.select('section#results.results.justify')



img_main=main[0].select('img')

count=1
img_range=img_main[1::2]



print(len(main))

print(len(img_range))


for i in img_range:
    #print(i)
    img_url=i['src']
    
    save_img(img_count,img_class,img_url)
    img_count+=1
b_id=61
Y_id=2
rand=1594292349217
random.randint(50,1002)
headers=random_headers()
url="https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p={}&tmpl=&nost=1&b={}&iid=Y.{}&ig=0aed4ab7b49a41b59c00000000f92686&rand={}".format(img_class,b_id,Y_id,rand)
for i in range(0,17):
    soup=get_next_main(url,headers)
    print(url)
    img_main=soup.select('img')
    img_range=img_main[1::2]
    print(len(img_range))
    for i in img_range:
        img_url=i['src']
        save_img(img_count,img_class,img_url)
        img_count+=1
    b_id=b_id+60
    
    Y_id=Y_id+1
    x=random.randint(50,1002)
    rand=rand-x
    print(b_id)
    url="https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p={}&tmpl=&nost=1&b={}&iid=Y.{}&ig=0aed4ab7b49a41b59c00000000f92686&rand={}".format(img_class,b_id,Y_id,rand)
    time.sleep(5)
print("finish")
# Out:
# mkdir name save_img has been create
# dir name egg has been create
# dir name tomoto has been create
# dir name 高麗菜 has been create
# dir name 小黃瓜 has been create
# dir name 紅蘿蔔 has been create
# dir name 馬鈴薯 has been create
# dir name 雞腿肉 has been create
# dir name 蘋果 has been create
# dir name 杏鮑菇 has been create
# dir name 白蘿蔔 has been create
# {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0'}
# 200
# 1
# 46
# {'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'}
# https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p=白蘿蔔&tmpl=&nost=1&b=61&iid=Y.2&ig=0aed4ab7b49a41b59c00000000f92686&rand=1594292349217
# 50
# 121
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
from datetime import datetime
url="https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p=馬鈴薯&tmpl=&nost=1&b=61&iid=Y.2&ig=0aed4ab7b49a41b59c00000000f92686&rand=1594292349217"
headers={'User-agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0'}

ss=requests.session()
res=ss.get(url,headers=headers)

json_string=res.text
inside_article= json.loads(json_string)
print(type(inside_article))
print(total)
test=inside_article['html']
total=inside_article['meta']['total']
#print(inside_article['html'])
print(type(inside_article['html']))
soup=BeautifulSoup(test,'html.parser')
img_main=soup.select('img')
img_range=img_main[1::2]
print(len(img_range))
for i in img_range:
    print(i['src'])
#print(len(inside_article['html']))
#print(inside_article.keys())
#print(inside_article.keys())
#egg
#https://tw.images.search.yahoo.com/search/images;_ylt=AwrtS3dH0AdfWHoAFEVt1gt.;_ylu=X3oDMTBsZ29xY3ZzBHNlYwNzZWFyY2gEc2xrA2J1dHRvbg--;_ylc=--?p=%E9%9B%9E%E8%9B%8B&fr=yfp-search-sb&fr2=sb-top-tw.images.search&ei=UTF-8&n=60&x=wrt
# https://tse4.mm.bing.net/th?id=OIP.rC0bUMUWOprTCedoh-nnYwHaFj&pid=Api&P=0&w=300&h=300
# https://tse4.mm.bing.net/th?id=OIP._ctvPD17XJK9KLWn45lt6AHaFj&pid=Api&P=0&w=300&h=300
# https://tse3.mm.bing.net/th?id=OIP.bo6bkfl0UgB56IuvEccraQEsDh&pid=Api&P=0&w=300&h=300
# https://tse1.mm.bing.net/th?id=OIP.flpkzfqLfc64AFwd-AFoRQEsDI&pid=Api&P=0&w=300&h=300
# https://tse2.mm.bing.net/th?id=OIP.eMJH3kFcjjFmaVGODiYnFQHaEK&pid=Api&P=0&w=300&h=300
# https://tse3.mm.bing.net/th?id=OIP.CBqmgEAS7xXbjdBTd3IjUQHaHa&pid=Api&P=0&w=300&h=300
# https://tse2.mm.bing.net/th?id=OIP.n8phOgU-QtVXeYfPv0GH9gHaFj&pid=Api&P=0&w=300&h=300
# ...

# %%
import time
def datetime2timestamp(dt, convert_to_utc=False):
''' Converts a datetime object to UNIX timestamp in milliseconds. '''
if isinstance(dt, datetime.datetime):
if convert_to_utc: # 是否轉化為UTC時間
dt = dt   datetime.timedelta(hours=-8) # 中國預設時區
timestamp = total_seconds(dt - EPOCH)
return long(timestamp)
return dt
test2=datetime2timestamp(dt)
print(test2)
# Out:
#   File "<ipython-input-70-38065b409fe0>", line 3
#     ''' Converts a datetime object to UNIX timestamp in milliseconds. '''
#                                                                         ^
# IndentationError: expected an indented block

# %%
#番茄，高麗菜，小黃瓜，紅蘿蔔，馬鈴薯，蘋果，雞腿肉，杏鮑菇，白蘿蔔，雞蛋 的圖片

# %%
img_class="馬鈴薯"
b_id=61
Y_id=2
rand=1594292349217
url="https://tw.images.search.yahoo.com/search/images;_ylt=AwrtSSggIghfEN4AAkZt1gt.;_ylu=X3oDMTBsZ29xY3ZzBHNlYwNzZWFyY2gEc2xrA2J1dHRvbg--;_ylc=?p={}&fr=yfp-search-sb&fr2=sb-top-tw.images.search&ei=UTF-8&n=60&x=wrt".format(img_class)
print(url)

url2="https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p={}&tmpl=&nost=1&b={}&iid=Y.{}&ig=0aed4ab7b49a41b59c00000000f92686&rand={}".format(img_class,b_id,Y_id,rand)
print(url2)
# Out:
# https://tw.images.search.yahoo.com/search/images;_ylt=AwrtSSggIghfEN4AAkZt1gt.;_ylu=X3oDMTBsZ29xY3ZzBHNlYwNzZWFyY2gEc2xrA2J1dHRvbg--;_ylc=?p=馬鈴薯&fr=yfp-search-sb&fr2=sb-top-tw.images.search&ei=UTF-8&n=60&x=wrt
# https://tw.images.search.yahoo.com/search/images?n=60&ei=UTF-8&fr=yfp-search-sb&fr2=sb-top-tw.images.search&o=js&p=馬鈴薯&tmpl=&nost=1&b=61&iid=Y.2&ig=0aed4ab7b49a41b59c00000000f92686&rand=1594292349217
